# %% [markdown]
# # Exercício 02

# %% [markdown]
# ### 1. Grave quatro sinais de voz ou adquirir,2 do sexo masculino e 2 do sexo feminino e, se possível, pelo menos 1 de criança;
# ### 2. Determine a frequência fundamental para sinais de voz por meio de, pelo menos, dois métodos diferentes (AMDF e Autocorrelação). Faça com que o programa detecte se o sinal de voz pertence ao gênero feminino, masculino, ou se é de criança (caso haja).
# ### 3. Use o software Praat para obter a frequência fundamental dos mesmos sinais e compare com o que você obteve.
# ### 4. Faça alguns comentários sobre os resultados obtidos, plote todos os gráficos, inclusive do software Praat.

# %%
import IPython
import sys
import os
import glob
import numpy as np
import matplotlib.pyplot as plt
from scipy.io import wavfile
from scipy.signal import find_peaks

if '..' not in sys.path:
    sys.path.insert(0, '..')
    
from modulos.sigproc import framesig
from modulos.faps import energia, ZCR
import pandas as pd

# %%
speech_list = glob.glob('../som/*.wav')
speech_list.sort()
speech_list
# Out:
# ['../som/avsn3.wav',
#  '../som/faban3.wav',
#  '../som/pedroivo.wav',
#  '../som/slnccn3.wav',
#  '../som/vjdvn3.wav']

# %%
choose_audio = speech_list[1]
IPython.display.Audio(f'{choose_audio}')
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
NomeArquivo = choose_audio
fs,sinal = wavfile.read(NomeArquivo)
Ts=1/fs

print(f'Frequência: {fs}Hz')
print(f'Amostras: {len(sinal)}')
print(f'Duração do sinal: {len(sinal)/fs}s')
# Out:
# Frequência: 22050Hz
# Amostras: 26400
# Duração do sinal: 1.1972789115646258s

# %%
amostras_ms = int(fs / 1000)
frame_time = 52
amostras_frame = amostras_ms * frame_time
nFrames = int(len(sinal) / amostras_frame)      
print(f'Número de amostras/frames : {amostras_frame}')
print ('Número de frames:', nFrames)
# Out:
# Número de amostras/frames : 1144
# Número de frames: 23

# %%
plt.figure(figsize=(20,5))
plt.plot(sinal)
plt.title('Sinal')
plt.xlabel('Frames')
plt.ylabel('Amplitude')
plt.grid()

# %% [markdown]
# ## Normalizando o sinal

# %%
max(abs(sinal))
# Out:
# 18053

# %% [raw]
# sinal = sinal / max(abs(sinal))
# t=(np.arange(len(sinal)))/fs
# assert min(sinal) >= -1 and max(sinal) <= 1

# %%
sinal
# Out:
# array([ 12,  16,  16, ..., 130, 135, 143], dtype=int16)

# %%
plt.figure(figsize=(20,5))
plt.figure(1)
plt.title('Sinal Original'), plt.xlabel('Amostras'), plt.ylabel('Amplitude Normalizada')  
plt.plot(sinal)
plt.grid()

# %%
import librosa

# %%
y, sr = librosa.load(choose_audio)

# %%
#y = y[7000:24000]
plt.figure(figsize=(20,5))
plt.figure(1)
plt.title('Sinal Original'), plt.xlabel('Amostras'), plt.ylabel('Amplitude Normalizada')  
plt.plot(y)
plt.grid()

# %%
fig1 = plt.figure(figsize=(20,5))
fig1, ax = plt.subplots()
auto_correlation = librosa.autocorrelate(y)
plt.plot(auto_correlation)
ax.set_xlim(0, 880*1)
# Out:
# (0.0, 880.0)

# %%
peaks = find_peaks(auto_correlation)[0]
peaks
# Out:
# array([ 122,  242,  361,  481,  601,  721,  841,  960, 1080, 1143, 1199,
#        1319, 1441, 1562, 1682, 1802, 1924, 2044, 2166, 2289, 2413, 2536,
#        2658, 2778, 2898, 3023, 3145, 3268, 3389, 3517, 3640, 3763, 3767,
#        3890, 4022, 4145, 4275, 4330, 4405, 4530, 4543, 4596, 4601, 4669,
#        4745, 4811, 4856, 4864, 4880, 4886, 4893, 4933, 4946, 4999, 5012,
#        5028, 5054, 5078, 5117, 5147, 5157, 5173, 5200, 5214, 5265, 5276,
#        5292, 5342, 5411, 5439, 5464, 5477, 5530, 5557, 5607, 5620, 5646,
#        5660, 5676, 5702, 5730, 5744, 5765, 5795, 5823, 5839, 5846, 5875,
#        5889, 5913, 5941, 5960, 5983, 6011, 6034, 6077, 6103, 6115, 6129,
#        6156, 6178, 6221, 6234, 6249, 6276, 6302, 6315, 6368, 6440, 6443,
#        6460, 6515, 6544, 6583, 6594, 6603, 6632, 6649, 6664, 6676, 6689,
#        6701, 6730, 6740, 6752, 6780, 6794, 6808, 6819, 6835, 6887, 6950,
#        6967, 7032, 7100, 7114, 7166, 7177, 7231, 7259, 7312, 7323, 7376,
#        7393, 7468, 7536, 7617, 7754, 7764, 7898, 7909, 7977, 8042, 8056,
#        8108, 8187, 8202, 8325, 8338, 8350, 8362, 8418, 8446, 8472, 8495,
#        8511, 8537, 8562, 8578, 8591, 8615, 8662, 8671, 8684, 8750, 8763,
#        8831, 8898, 8973, 8989, 9016, 9043, 9067, 9080, 9093, 9110, 9144,
#        9200, 9259, 9327, 9337, 9351, 9376, 9403, 9447, 9466, 9489, 9568,
#        9580, 9607, 9644, 9715, 9730, 9810, 9834, 9860, 9883, 9923, 9949,
#        9963, 9981, 9986])

# %%
fig1, ax = plt.subplots()
plt.plot(auto_correlation)
plt.plot(peaks, auto_correlation[peaks], "x")
ax.set_xlim(0, 880*1)
# Out:
# (0.0, 880.0)

# %%
auto_correlation[82]
# Out:
# -55.888714109547436

# %%
max_to_min = np.sort(auto_correlation[peaks])[::-1]
max_to_min
# Out:
# array([ 1.05827771e+02,  6.89521630e+01,  5.53970500e+01,  4.57979469e+01,
#         4.06113713e+01,  4.01090834e+01,  3.47839195e+01,  3.25225739e+01,
#         3.12730715e+01,  3.02555052e+01,  2.99135998e+01,  2.88436974e+01,
#         2.63597588e+01,  2.23790518e+01,  2.09370691e+01,  1.99930303e+01,
#         1.97979835e+01,  1.95057808e+01,  1.93457761e+01,  1.81839981e+01,
#         1.71647304e+01,  1.54942355e+01,  1.37787639e+01,  1.24850322e+01,
#         1.10182358e+01,  1.00310231e+01,  9.37696828e+00,  8.90737199e+00,
#         8.78281226e+00,  8.47152794e+00,  7.72930503e+00,  7.72294309e+00,
#         7.41934357e+00,  6.90055143e+00,  6.08960028e+00,  5.01308887e+00,
#         4.30260726e+00,  3.17681461e+00,  3.09231102e+00,  2.95453569e+00,
#         2.86277410e+00,  2.73712198e+00,  2.56582856e+00,  2.51476487e+00,
#        -8.49796842e-01, -9.04726872e-01, -9.24952128e-01, -9.59307196e-01,
#        -1.02556292e+00, -1.03023712e+00, -1.04217327e+00, -1.11436390e+00,
#        -1.12950161e+00, -1.26521187e+00, -1.34316948e+00, -1.34535792e+00,
#        -1.38490256e+00, -1.39170099e+00, -1.48465179e+00, -1.49367617e+00,
#        -1.52693658e+00, -1.54567613e+00, -1.55066270e+00, -1.56678600e+00,
#        -1.58175321e+00, -1.59379535e+00, -1.62056588e+00, -1.88846273e+00,
#        -2.61081673e+00, -2.64138419e+00, -4.34847798e+00, -2.05102480e+01])

# %%
t1 = np.where(auto_correlation == max_to_min[0])[0][0]
t2 = np.where(auto_correlation == max_to_min[1])[0][0]
print(t1)
print(t2)
# Out:
# 122
# 242

# %%
pitch = fs/(t2 - t1)

limiares = [105, 213, 290] 
resultado = min(limiares, key=lambda x:abs(x-pitch))
print(f'O valor de pitch é {pitch}\n')
if resultado == 105:
    print("A voz aparenta ser masculina")
elif resultado == 213:
    print("A voz aparenta ser feminina")
elif resultado == 290:
    print("A voz aparenta ser feminina")
# Out:
# O valor de pitch é 183.75
#
# A voz aparenta ser feminina

# %% [markdown]
# ![praat](../extras/fabio_pitch.png "Pitch de Fábio")

# %% [markdown]
# ![praat](../extras/vinicius_pitch.png "Pitch de Vinicius")

# %% [markdown]
# ![praat](../extras/adriana_pitch.png "Pitch de Adriana")

# %% [markdown]
# ![praat](../extras/silvanna_pitch.png "Pitch de Silvanna")

# %% [markdown]
# # AMDF

# %%
def amdf(sinal, amostras): # Função para calcular a AMDF
    length = len(sinal)
    AMDF = np.zeros(amostras) # Armazena os resultados da AMDF, com um novo array preenchido com zeros

    for d in range(0, amostras):
        sum = 0.0

        for index in range(d, length-d-1):
            sum += abs(sinal[index] - sinal[index + d])

        AMDF[d] = (sum/length)

    return AMDF

# %%
amdf = amdf(y,1000)

# %%
plt.plot(amdf)

# %%
peaks = find_peaks(-amdf, distance=50)[0]

# %%
peaks
# Out:
# array([120, 240, 360, 479, 598, 718, 859, 912, 979])

# %%
fig1, ax = plt.subplots()
plt.plot(amdf)
plt.plot(peaks, amdf[peaks], "x")

# %%
max_to_min = np.sort(amdf[peaks])
max_to_min
# Out:
# array([0.04861747, 0.07468802, 0.08293339, 0.08378399, 0.0855821 ,
#        0.08614578, 0.08697131, 0.08921454, 0.1077687 ])

# %%
t1 = np.where(amdf == max_to_min[0])[0][0]
t2 = np.where(amdf == max_to_min[1])[0][0]
print(t1)
print(t2)
# Out:
# 120
# 240

# %%
pitch = fs/(t2 - t1)

limiares = [105, 213, 290] 
resultado = min(limiares, key=lambda x:abs(x-pitch))
print(f'O valor de pitch é {pitch}\n')
if resultado == 105:
    print("A voz aparenta ser masculina")
elif resultado == 213:
    print("A voz aparenta ser feminina")
elif resultado == 290:
    print("A voz aparenta ser feminina")
# Out:
# O valor de pitch é 183.75
#
# A voz aparenta ser feminina
